# %%
import pathlib
from our_dataset.dataset import load_dataset
import plotly.io as pio

pio.templates.default = "project"
import plotly.express as px
px.defaults.width = 900 #type:ignore
px.defaults.height = 500 #type:ignore
ds = load_dataset(base_path=pathlib.Path("../Data/Cryptojacking Network Traffic 2021"))

# %%
px.bar((ds.df['is_malicious'].map(bool)).value_counts().to_frame().reset_index(),x='is_malicious',color='is_malicious',y='count',log_y=True).show()
None
